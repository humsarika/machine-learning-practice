# %% [markdown]
# <a href="https://colab.research.google.com/github/sarika-kushwaha/data-science-colab-notebook/blob/main/I_O_SQLdatabase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from sqlalchemy import create_engine

# %%
temp_db = create_engine('sqlite:///:memory:')

# %%
df = pd.DataFrame(data= np.random.randint(low=0,high = 100,size = (4,4)),columns = ['A','B','C','D'])

# %%
df
# Out:
#     A   B   C   D
# 0  99  25   9  59
# 1  77  43  92  46
# 2  87  47  75  47
# 3  28  73  25  78

# %%
df.to_sql(name = 'new_table',con = temp_db,index = False)

# %%
new_df = pd.read_sql(sql='new_table',con = temp_db)

# %%
new_df
# Out:
#     A   B   C   D
# 0  99  25   9  59
# 1  77  43  92  46
# 2  87  47  75  47
# 3  28  73  25  78

# %%
result = pd.read_sql_query(sql = 'SELECT A,B FROM new_table',con = temp_db)

# %%
result
# Out:
#     A   B
# 0  99  25
# 1  77  43
# 2  87  47
# 3  28  73
