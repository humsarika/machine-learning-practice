# %% [markdown]
# <a href="https://colab.research.google.com/github/sarika-kushwaha/data-science-colab-notebook/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pandas documentation - https://pandas.pydata.org/docs

# %% [markdown]
# ### **Series - data structure in pandas**

# %%
import numpy as np
import pandas as pd

# %%
help(pd.Series)

# %%
myindex = ["USA","Canada","Mexico"]

# %%
mydata = [1776,1876,1988]

# %%
myser = pd.Series(data = mydata , index = myindex)

# %%
myser
# Out:
# USA       1776
# Canada    1876
# Mexico    1988
# dtype: int64

# %%
myser[0]
# Out:
# 1776

# %%
myser["USA"]
# Out:
# 1776

# %%
ages = {"sam" : 10 , "john" : 20 , "joe" :14 }

# %%
pd.Series(ages)
# Out:
# sam     10
# john    20
# joe     14
# dtype: int64

# %%
EXERCISE
print the expense of bob using pandas
expenses = {"Andrew":200,"Bob":150,"Claire":450} ----> this is a dictionary named expenses
pd.Series(expenses)
expenses = pd.Series({"Andrew":200,"Bob":150,"Claire":450})
bob_expenses = expenses["Bob"]
bob_expenses
# Out:
# 150

# %%
q1 = {"Japan":80,"China":450,"India":200,"USA":250}
q2 = {"Brazil":100,"China":500,"India":210,"USA":260}

# %%
sales_q1 = pd.Series(q1)
sales_q1

# %%
sales_q1['Japan']
# Out:
# 80

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
sales_q2 = pd.Series(q2)
sales_q2
# Out:
# Brazil    100
# China     500
# India     210
# USA       260
# dtype: int64

# %%
[1,2]*2
# Out:
# [1, 2, 1, 2]

# %%
np.array([1,2])*2
# Out:
# array([2, 4])

# %%
sales_q2 -50
# Out:
# Brazil     50
# China     450
# India     160
# USA       210
# dtype: int64

# %%
sales_q1 + sales_q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %% [markdown]
# NaN = Not a number

# %%
sales_q1.add(sales_q2,fill_value = 0) # assigning fill value 0 so it will not give Nan and add 0 ton that number
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
print(sales_q1.dtype)
new = sales_q1.add(sales_q2,fill_value = 0)
print(new.dtype)
# Out:
# int64
# float64

# %% [markdown]
# ### **DATA FRAMES**
#
# > A group of pandas series objects which shares same index

# %%
import numpy as np 
import pandas as pd

# %%
how to create a data frame
np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ["gh","fg","ty","jj"]# rows

# %%
mycol = ["jan","feb","mar"] #columns

# %%
df = pd.DataFrame(mydata)
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(data = mydata , index = myindex)
df
# Out:
#      0   1   2
# gh  95  11  81
# fg  70  63  87
# ty  75   9  77
# jj  40   4  63

# %%
df = pd.DataFrame(data = mydata , index = myindex,columns = mycol)
df
# Out:
#     jan  feb  mar
# gh   95   11   81
# fg   70   63   87
# ty   75    9   77
# jj   40    4   63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, gh to jj
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   jan     4 non-null      int64
#  1   feb     4 non-null      int64
#  2   mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %% [markdown]
# pwd -
#
# > present working directory

# %%
import pandas as pd
df = pd.read_csv("Sample100.csv")

# %%
df.columns
# Out:
# Index(['Serial Number', 'Company Name', 'Employee Markme', 'Description',
#        'Leave'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=99, step=1)

# %%
df.head() # shows first 5 rows
# Out:
#    Serial Number               Company Name  Employee Markme  \
# 0   9.788190e+12             TALES OF SHIVA             Mark
# 1   9.780100e+12  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9.780200e+12                   MY KUMAN             Mark
# 3   9.780010e+12    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9.780550e+12           THE BLACK CIRCLE             Mark
#
#           Description  Leave
# 0                mark      0
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0

# %%
df.head(10) # shows first 10 rows
# Out:
#    Serial Number                         Company Name  Employee Markme  \
# 0   9.788190e+12                       TALES OF SHIVA             Mark
# 1   9.780100e+12            1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9.780200e+12                             MY KUMAN             Mark
# 3   9.780010e+12              THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9.780550e+12                     THE BLACK CIRCLE             Mark
# 5   9.788130e+12        THE THREE LAWS OF PERFORMANCE             Mark
# 6   9.789380e+12                    CHAMarkKYA MANTRA             Mark
# 7   9.788180e+12                             59.FLAGS             Mark
# 8   9.780740e+12  THE POWER OF POSITIVE THINKING FROM             Mark
# 9   9.789380e+12           YOU CAN IF YO THINK YO CAN            PEALE
#
#           Description  Leave
# 0                mark      0
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0
# ...

# %%
df.tail()
# Out:
#     Serial Number                   Company Name Employee Markme Description  \
# 94   9.788180e+12  MORE STORIES FROM THE JATAKAS            Mark         ACK
# 95   9.788180e+12           MORE TALES OF BIRBAL               -         ACK
# 96   9.788180e+12         TALES FROM THE JATAKAS               -         ACK
# 97   9.788180e+12               RAMarkS OF MEWAR               -         ACK
# 98   9.788180e+12       THE SONS OF THE PANDAVAS               -         ACK
#
#     Leave
# 94      0
# 95      0
# 96      0
# 97      0
# 98      0

# %%
df.tail(10)
# Out:
#     Serial Number                     Company Name Employee Markme  \
# 89   9.788180e+12  MORE TALES FROM THE PANCHTANTRA     AMarkNT PAL
# 90   9.788180e+12       THE GREAT MUGHALS {5-IN-1}        AMarkNT.
# 91   9.788180e+12                FAMOUS SCIENTISTS            Mark
# 92   9.788180e+12                         KOMarkRK            Mark
# 93   9.788180e+12                 THE MUGHAL COURT         REEMark
# 94   9.788180e+12    MORE STORIES FROM THE JATAKAS            Mark
# 95   9.788180e+12             MORE TALES OF BIRBAL               -
# 96   9.788180e+12           TALES FROM THE JATAKAS               -
# 97   9.788180e+12                 RAMarkS OF MEWAR               -
# 98   9.788180e+12         THE SONS OF THE PANDAVAS               -
#
#    Description  Leave
# 89         ACK      0
# 90         ACK      0
# 91         ACK      0
# 92         ACK      0
# 93         ACK      0
# 94         ACK      0
# 95         ACK      0
# 96         ACK      0
# ...

# %%
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    99 non-null     float64
#  1   Company Name     99 non-null     object
#  2   Employee Markme  97 non-null     object
#  3   Description      99 non-null     object
#  4   Leave            99 non-null     int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.0+ KB

# %%
# df.describe()
# Out:
#        Serial Number      Leave
# count   9.900000e+01  99.000000
# mean    9.687304e+12   0.818182
# std     9.827208e+11   2.158815
# min     8.187776e+09   0.000000
# 25%     9.781740e+12   0.000000
# 50%     9.788180e+12   0.000000
# 75%     9.789380e+12   0.500000
# max     9.789390e+12  10.000000

# %%
# df.describe().transpose()
# Out:
#                count          mean           std           min           25%  \
# Serial Number   99.0  9.687304e+12  9.827208e+11  8.187776e+09  9.781740e+12
# Leave           99.0  8.181818e-01  2.158815e+00  0.000000e+00  0.000000e+00
#
#                         50%           75%           max
# Serial Number  9.788180e+12  9.789380e+12  9.789390e+12
# Leave          0.000000e+00  5.000000e-01  1.000000e+01

# %% [markdown]
# DATA FRAMES
#
#
# > WORKING WITH COLUMNS

# %%
# pwd
# Out:
# '/content'

# %%
# import pandas as pd
# df = pd.read_csv("1000 Sales Records.csv")
# df
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
# df["Country"]
# Out:
# 0                     Libya
# 1                    Canada
# 2                     Libya
# 3                     Japan
# 4                      Chad
#                ...
# 995              Azerbaijan
# 996                 Georgia
# 997    United Arab Emirates
# 998                 Finland
# 999                Portugal
# Name: Country, Length: 1000, dtype: object

# %%
# type(df['Country'])
# Out:
# pandas.core.series.Series

# %%
# mycols = ['Country','Item Type']
# df[mycols]
# Out:
#                   Country   Item Type
# 0                   Libya   Cosmetics
# 1                  Canada  Vegetables
# 2                   Libya   Baby Food
# 3                   Japan      Cereal
# 4                    Chad      Fruits
# ..                    ...         ...
# 995            Azerbaijan      Snacks
# 996               Georgia   Baby Food
# 997  United Arab Emirates  Vegetables
# 998               Finland   Household
# 999              Portugal      Cereal
#
# [1000 rows x 2 columns]

# %%
# df['profit_from_per_person'] = df['Total Profit']/ df['Unit Price']
# df
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
# df.drop('profit_from_per_person',axis = 1)
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
# df
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
# df.drop('profit_from_per_person',axis = 1,inplace = True) # '''inplace = True''' will delete that column permanently

# %%
# df.shape
# Out:
# (1000, 14)

# %%
# df.shape[1]
# Out:
# 14

# %% [markdown]
# **Data frames -**
#
# > working with rows

# %%
# df.head(10)
# Out:
#                               Region     Country   Item Type Sales Channel  \
# 0       Middle East and North Africa       Libya   Cosmetics       Offline
# 1                      North America      Canada  Vegetables        Online
# 2       Middle East and North Africa       Libya   Baby Food       Offline
# 3                               Asia       Japan      Cereal       Offline
# 4                 Sub-Saharan Africa        Chad      Fruits       Offline
# 5                             Europe     Armenia      Cereal        Online
# 6                 Sub-Saharan Africa     Eritrea      Cereal        Online
# 7                             Europe  Montenegro     Clothes       Offline
# 8  Central America and the Caribbean     Jamaica  Vegetables        Online
# 9              Australia and Oceania        Fiji  Vegetables       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# ...

# %%
# df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# df.set_index("Order ID")
# Out:
#                                  Region               Country   Item Type  \
# Order ID
# 686800706  Middle East and North Africa                 Libya   Cosmetics
# 185941302                 North America                Canada  Vegetables
# 246222341  Middle East and North Africa                 Libya   Baby Food
# 161442649                          Asia                 Japan      Cereal
# 645713555            Sub-Saharan Africa                  Chad      Fruits
# ...                                 ...                   ...         ...
# 534085166  Middle East and North Africa            Azerbaijan      Snacks
# 590768182                        Europe               Georgia   Baby Food
# 524363124  Middle East and North Africa  United Arab Emirates  Vegetables
# 289606320                        Europe               Finland   Household
# 811546599                        Europe              Portugal      Cereal
#
# ...

# %%
# df = df.reset_index()
# df
# Out:
#      level_0  index                        Region               Country  \
# 0          0      0  Middle East and North Africa                 Libya
# 1          1      1                 North America                Canada
# 2          2      2  Middle East and North Africa                 Libya
# 3          3      3                          Asia                 Japan
# 4          4      4            Sub-Saharan Africa                  Chad
# ..       ...    ...                           ...                   ...
# 995      995    995  Middle East and North Africa            Azerbaijan
# 996      996    996                        Europe               Georgia
# 997      997    997  Middle East and North Africa  United Arab Emirates
# 998      998    998                        Europe               Finland
# 999      999    999                        Europe              Portugal
#
#       Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
# df
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
# df.set_index("Order ID")
# Out:
#                                  Region               Country   Item Type  \
# Order ID
# 686800706  Middle East and North Africa                 Libya   Cosmetics
# 185941302                 North America                Canada  Vegetables
# 246222341  Middle East and North Africa                 Libya   Baby Food
# 161442649                          Asia                 Japan      Cereal
# 645713555            Sub-Saharan Africa                  Chad      Fruits
# ...                                 ...                   ...         ...
# 534085166  Middle East and North Africa            Azerbaijan      Snacks
# 590768182                        Europe               Georgia   Baby Food
# 524363124  Middle East and North Africa  United Arab Emirates  Vegetables
# 289606320                        Europe               Finland   Household
# 811546599                        Europe              Portugal      Cereal
#
# ...

# %%
# df.reset_index()
# Out:
#      index                        Region               Country   Item Type  \
# 0        0  Middle East and North Africa                 Libya   Cosmetics
# 1        1                 North America                Canada  Vegetables
# 2        2  Middle East and North Africa                 Libya   Baby Food
# 3        3                          Asia                 Japan      Cereal
# 4        4            Sub-Saharan Africa                  Chad      Fruits
# ..     ...                           ...                   ...         ...
# 995    995  Middle East and North Africa            Azerbaijan      Snacks
# 996    996                        Europe               Georgia   Baby Food
# 997    997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998    998                        Europe               Finland   Household
# 999    999                        Europe              Portugal      Cereal
#
# ...

# %%
# df.drop("index",axis=1,inplace=True)

# %%
# df
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
# one_row = df.iloc[0]
# one_row
# Out:
# Region            Middle East and North Africa
# Country                                  Libya
# Item Type                            Cosmetics
# Sales Channel                          Offline
# Order Priority                               M
# Order Date                          10/18/2014
# Order ID                             686800706
# Ship Date                           10/31/2014
# Units Sold                                8446
# Unit Price                               437.2
# Unit Cost                               263.33
# Total Revenue                        3692591.2
# Total Cost                          2224085.18
# Total Profit                        1468506.02
# Name: 0, dtype: object

# %%
# df = df.append(one_row)

# %%
# df
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
# 0    Middle East and North Africa                 Libya   Cosmetics
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
# df.drop(0)
# Out:
#                            Region               Country   Item Type  \
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# 5                          Europe               Armenia      Cereal
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 1          Online              M  11-07-2011  185941302  12-08-2011
# ...

# %% [markdown]
# DATA FRAMES-
#
#
# >Conditional Filtering

# %%
# df = pd.read_csv("1000 Sales Records.csv")
# df.head(4)
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M  11-07-2011  185941302  12-08-2011        3018      154.06
# 2              C  10/31/2016  246222341  12-09-2016        1517      255.28
# 3              C  04-10-2010  161442649  05-12-2010        3322      205.70
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# 1      90.93      464953.08   274426.74     190526.34
# 2     159.42      387259.76   241840.14     145419.62
# ...

# %%
# Sales_greater_than_9950 = df['Units Sold'] > 9950
# Sales_greater_than_9950
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Units Sold, Length: 1000, dtype: bool

# %%
# df[Sales_greater_than_9950] # only 4 rows are their in which total units sold is greater than 9950
# Out:
#                     Region        Country  Item Type Sales Channel  \
# 146                 Europe         Serbia     Snacks       Offline
# 345                 Europe     Luxembourg  Baby Food       Offline
# 702     Sub-Saharan Africa  Guinea-Bissau    Clothes        Online
# 817  Australia and Oceania    New Zealand       Meat       Offline
#
#     Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 146              C   9/20/2013  547748982  10/14/2013        9951      152.58
# 345              H   6/30/2011  393620669  08-02-2011        9958      255.28
# 702              L   6/18/2015  867360150  07-01-2015        9998      109.28
# 817              H  06-02-2013  969616687   6/28/2013        9980      421.89
#
#      Unit Cost  Total Revenue  Total Cost  Total Profit
# 146      97.44     1518323.58   969625.44     548698.14
# 345     159.42     2542078.24  1587504.36     954573.88
# 702      35.84     1092581.44   358328.32     734253.12
# ...

# %%
# import pandas as pd
# Index = [0,1,2,3,4,5]
# mydata ={'name' :["sam","ross","john","Gux","lez","gommy"],'age':[20,21,22,23,19,20],'yob': [2002,2001,2000,1999,2003,2002]}
# mycol = ['name','age','yob']
# mydata
# Out:
# {'age': [20, 21, 22, 23, 19, 20],
#  'name': ['sam', 'ross', 'john', 'Gux', 'lez', 'gommy'],
#  'yob': [2002, 2001, 2000, 1999, 2003, 2002]}

# %%
# df = pd.DataFrame(data=mydata , index = Index,columns = mycol)
# df
# Out:
#     name  age   yob
# 0    sam   20  2002
# 1   ross   21  2001
# 2   john   22  2000
# 3    Gux   23  1999
# 4    lez   19  2003
# 5  gommy   20  2002

# %%
# df.iloc[1]
# Out:
# name    ross
# age       21
# yob     2001
# Name: 1, dtype: object

# %%
# df.set_index("name")
# Out:
#        age   yob
# name
# sam     20  2002
# ross    21  2001
# john    22  2000
# Gux     23  1999
# lez     19  2003
# gommy   20  2002

# %%
# df.reset_index()
# Out:
#    index   name  age   yob
# 0      0    sam   20  2002
# 1      1   ross   21  2001
# 2      2   john   22  2000
# 3      3    Gux   23  1999
# 4      4    lez   19  2003
# 5      5  gommy   20  2002

# %%
# df
# Out:
#     name  age   yob
# 0    sam   20  2002
# 1   ross   21  2001
# 2   john   22  2000
# 3    Gux   23  1999
# 4    lez   19  2003
# 5  gommy   20  2002

# %%
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     6 non-null      int64
#  2   yob     6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 192.0+ bytes

# %%
# Gender = ["F","F","M","M","M","M"]
# df.insert(1,"Gender",Gender,True)
df
# Out:
#     name Gender  age   yob
# 0    sam      F   20  2002
# 1   ross      F   21  2001
# 2   john      M   22  2000
# 3    Gux      M   23  1999
# 4    lez      M   19  2003
# 5  gommy      M   20  2002

# %%
# df['Gender']
# Out:
# 0    F
# 1    F
# 2    M
# 3    M
# 4    M
# 5    M
# Name: Gender, dtype: object

# %%
# df['Gender']=="M"
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# Name: Gender, dtype: bool

# %%
# df[df['Gender']=='M']
# Out:
#     name Gender  age   yob
# 2   john      M   22  2000
# 3    Gux      M   23  1999
# 4    lez      M   19  2003
# 5  gommy      M   20  2002

# %%
# df[(df['age']>20) | (df['Gender']=='M')]
# Out:
#     name Gender  age   yob
# 1   ross      F   21  2001
# 2   john      M   22  2000
# 3    Gux      M   23  1999
# 4    lez      M   19  2003
# 5  gommy      M   20  2002

# %%
# df[(df['age']>20) & (df['Gender']=='M')]
# Out:
#    name Gender  age   yob
# 2  john      M   22  2000
# 3   Gux      M   23  1999

# %%
# df[(df['yob']==2002) | (df['yob']==2001)]
# Out:
#     name Gender  age   yob
# 0    sam      F   20  2002
# 1   ross      F   21  2001
# 5  gommy      M   20  2002

# %%
# options = [2001,2002]
# df[df['yob'].isin(options)]
#            or 
# df[df['yob'].isin([2001,2002])]
# Out:
#     name Gender  age   yob
# 0    sam      F   20  2002
# 1   ross      F   21  2001
# 5  gommy      M   20  2002

# %% [markdown]
# ### **USEFULL METHODS**

# %% [markdown]
# > .apply()

# %%
# import pandas as pd
# import numpy as np

# %%
# df = pd.read_csv('1000 Sales Records.csv')

# %%
# df.head()

# %%
# df.info()

# %%
# str(12345678)[0]

# %%
# str(12345678)[-4:]

# %%
# def last_four(num):
#   return str(num)[-4:]

# %%
# last_four(1234432222)

# %%
# df['Order ID'].apply(last_four)

# %%
# df['last four'] = df['Order ID'].apply(last_four)

# %%
# df

# %%
# df['Unit Price'].mean()

# %%
# def yelp(price):
#   if price < 100:
#       return '$'
#   elif price >=100 and price < 200:
#     return "$$"
#   else:
#     return "$$$"

# %%
# df['yelp'] = df['Unit Price'].apply(yelp)

# %%
# df

# %%
# df['yelp']

# %% [markdown]
# > Apply with multiple columns

# %%
# lambda num: num*2 # lambda function

# %%
# df['Unit Price'].apply(lambda num: num + 10) # adding 10 to every row of Unit Price

# %%
# df

# %%
# def quality(Total_cost , Total_profit):
#   if Total_profit/Total_cost > 100:
#     return 'generous'
#   else:
#     return 'other'

# %%
# quality(123.45,23)

# %%
# df['Quality']= df[['Total Cost','Total Profit']].apply(lambda df: quality(df['Total Cost'],df['Total Profit']),axis = 1)
# df
# or
# df['Quality'] = np.vectorize(quality)(df['Total Cost'],df['Total Profit'])

# %%
# df.drop('Quality',axis = 1,inplace = True)

# %%
# df

# %%
# import timeit

# %%
# # code snippet to be executed only once
# setup = '''
# import pandas as pd
# import numpy as np
# df = pd.read_csv('1000 Sales Records.csv' )
# def quality(Total_cost , Total_profit):
#   if Total_profit/Total_cost > 100:
#     return 'generous'
#   else:
#     return 'other'
#     '''

# %%
# # code snippet whose execution time is to be measured
# st1 = '''
# df['Quality']= df[['Total Cost','Total Profit']].apply(lambda df: quality(df['Total Cost'],df['Total Profit']),axis = 1)
# '''
# st2 = '''
# df['Quality'] = np.vectorize(quality)(df['Total Cost'],df['Total Profit'])
# '''

# %%
# timeit.timeit(setup = setup , stmt = st1,number = 1000)

# %%
# timeit.timeit(setup = setup , stmt = st2,number = 1000)

# %% [markdown]
# >Describing And Sorting

# %%
# df = pd.read_csv('1000 Sales Records.csv')

# %%
# df.describe()

# %%
# df.describe().transpose()

# %%
# df.sort_values("Units Sold") # sorts in ascending order by default

# %%
# df.sort_values("Units Sold",ascending = False)

# %%
# df['Units Sold'].max()

# %%
# df['Units Sold'].min()

# %%
# df['Units Sold'].idxmin()

# %%
# df.iloc[590]
# or 
# df.iloc[df['Units Sold'].idxmin()]

# %%
# df['Units Sold'].idxmax()

# %%
# df.corr()

# %%
# df.head()

# %%
# df['Country'].value_counts()

# %%
# df['Item Type'].unique()

# %%
# df['Item Type'].nunique()

# %%
# df['Country'].replace(['Libya'],['India'])
# df['Country'].replace(['Libya','Chad'],['India','Nepal'])
# df

# %%
# mymap = {'Libya': 'India','Chad':'Nepal'}
# df['Country'].map(mymap)

# %% [markdown]
# **missing data**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('movies.csv')

# %%
np.nan
# Out:
# nan

# %%
pd.NaT
# Out:
# NaT

# %%
np.nan == np.nan
# Out:
# False

# %%
myvar = np.nan

# %%
myvar is np.nan
# Out:
# True

# %%
df= pd.read_csv('movies.csv')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.isnull()
# Out:
#        name  rating  genre   year  released  score  votes  director  writer  \
# 0     False   False  False  False     False  False  False     False   False
# 1     False   False  False  False     False  False  False     False   False
# 2     False   False  False  False     False  False  False     False   False
# 3     False   False  False  False     False  False  False     False   False
# 4     False   False  False  False     False  False  False     False   False
# ...     ...     ...    ...    ...       ...    ...    ...       ...     ...
# 7663  False    True  False  False     False  False  False     False   False
# 7664  False    True  False  False     False  False  False     False   False
# 7665  False    True  False  False     False  False  False     False   False
# 7666  False    True  False  False     False   True   True     False   False
# 7667  False    True  False  False     False  False  False     False   False
#
#        star  country  budget  gross  company  runtime
# ...

# %%
df.notnull()
# Out:
#       name  rating  genre  year  released  score  votes  director  writer  \
# 0     True    True   True  True      True   True   True      True    True
# 1     True    True   True  True      True   True   True      True    True
# 2     True    True   True  True      True   True   True      True    True
# 3     True    True   True  True      True   True   True      True    True
# 4     True    True   True  True      True   True   True      True    True
# ...    ...     ...    ...   ...       ...    ...    ...       ...     ...
# 7663  True   False   True  True      True   True   True      True    True
# 7664  True   False   True  True      True   True   True      True    True
# 7665  True   False   True  True      True   True   True      True    True
# 7666  True   False   True  True      True  False  False      True    True
# 7667  True   False   True  True      True   True   True      True    True
#
#       star  country  budget  gross  company  runtime
# ...

# %%
df[df['rating'].isnull()]
# Out:
#                      name rating      genre  year  \
# 78                Babylon    NaN      Drama  1980
# 91    Mantis Fist Fighter    NaN     Action  1980
# 102              Das Boot    NaN  Adventure  1981
# 298   The State of Things    NaN      Drama  1982
# 464            White Star    NaN      Drama  1983
# ...                   ...    ...        ...   ...
# 7663         More to Life    NaN      Drama  2020
# 7664          Dream Round    NaN     Comedy  2020
# 7665        Saving Mbango    NaN      Drama  2020
# 7666         It's Just Us    NaN      Drama  2020
# 7667            Tee em el    NaN     Horror  2020
#
#                                released  score     votes           director  \
# 78       November 1980 (United Kingdom)    7.4    1300.0       Franco Rosso
# 91         July 9, 1982 (United States)    6.7     230.0       Wing-Cho Yip
# 102   February 10, 1982 (United States)    8.3  237000.0  Wolfgang Petersen
# ...
