# %% [markdown]
# <a href="https://colab.research.google.com/github/humsarika/machine-learning-practice/blob/main/pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# sample_data/  tips.csv

# %%
df = pd.read_csv("tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head() # by default gives 5 rows from start
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.head(10) #  gives 10 rows from start
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
df.tail() # by default gives 5 rows from last
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.tail(10) # gives 10 rows from last
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 234    Tracy Douglas  4097938155941930    Sat7220
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %% [markdown]
# # **Columns**

# %%
df["total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
# mycol = ['total_bill','tip']
# df[mycol]

# or
df[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df['price_perperson'] = np.round(df['total_bill']/ df['size'],2)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  price_perperson
# 0  Christy Cunningham  3560325168603410    Sun2959             8.49
# 1      Douglas Tucker  4478071379779230    Sun4608             3.45
# 2      Travis Walters  6011812112971322    Sun4458             7.00
# 3    Nathaniel Harris  4676137647685994    Sun5260            11.84
# 4        Tonya Carter  4832732618637221    Sun2251             6.15

# %%
# removing columns
# df.drop('total_amount_paid') we have to provide axis also,default axis is 0 which means row, if we we will not provide axis it will give error - KeyError['total_amount_paid'] not found in axis"
df.drop('price_perperson',axis=1) # its not a permanent change
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.head()
# the total_amount_paid column is still there
# tomake it permanent we need to set inplace attribute to true
# df.drop('total_amount_paid',axis=1, inplace = True) # its not a permanent change

# but recommended method is to dolike this
# df = df.drop('total_amount_paid',axis=1)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  price_perperson
# 0  Christy Cunningham  3560325168603410    Sun2959             8.49
# 1      Douglas Tucker  4478071379779230    Sun4608             3.45
# 2      Travis Walters  6011812112971322    Sun4458             7.00
# 3    Nathaniel Harris  4676137647685994    Sun5260            11.84
# 4        Tonya Carter  4832732618637221    Sun2251             6.15

# %%
# df['payment ID'] = df['day'] + df['Payer Name'][:4].astype(str)
# i want to create a payment id using day and first name and last 4 digit of cc number

# %%
df.set_index('Payment ID') # to set index
# this change is temporary

df = df.set_index('Payment ID') # this change is permanent
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df.reset_index('Payment ID') # reset index
# this change is temporary

df = df.reset_index('Payment ID') # this change is permanent
df
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  price_perperson
# ...

# %%
df.iloc[0] #Purely integer-location based indexing for selection by position it will all detailsof data of row 1
# Out:
# Payment ID                     Sun2959
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# price_perperson                   8.49
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
#
#    price_per_person          Payer Name         CC Number  price_perperson
# 0              8.49  Christy Cunningham  3560325168603410             8.49
# 1              3.45      Douglas Tucker  4478071379779230             3.45
# 2              7.00      Travis Walters  6011812112971322             7.00

# %%
df
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number  price_perperson
# ...

# %%
df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
#
#             price_perperson
# Payment ID
# Sun2959                8.49
# Sun4608                3.45
# Sun4458                7.00
# ...

# %%
df.loc['Sun2251'] #Access a group of rows and columns by label(s)
# Out:
# total_bill                     24.59
# tip                             3.61
# sex                           Female
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               4
# price_per_person                6.15
# Payer Name              Tonya Carter
# CC Number           4832732618637221
# price_perperson                 6.15
# Name: Sun2251, dtype: object

# %%
# dropping a row
df.drop('Sun2251') #its not deleted permanently unless we reasign it
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
# adding  new row
new_row = df.iloc[0]
new_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# price_perperson                   8.49
# Name: Sun2959, dtype: object

# %%
# df = df.append(new_row) appende is no longer vailble in pandas version 2 or above
df = pd.concat([df, pd.DataFrame([new_row])])

# %%
df
# Out:
#          total_bill   tip     sex smoker   day    time  size  \
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ...             ...   ...     ...    ...   ...     ...   ...
# Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
#
#          price_per_person          Payer Name         CC Number  \
# Sun2959              8.49  Christy Cunningham  3560325168603410
# Sun4608              3.45      Douglas Tucker  4478071379779230
# ...

# %% [markdown]
# ## **Conditional formatting**

# %%
df
# Out:
#          total_bill   tip     sex smoker   day    time  size  \
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ...             ...   ...     ...    ...   ...     ...   ...
# Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
#
#          price_per_person          Payer Name         CC Number  \
# Sun2959              8.49  Christy Cunningham  3560325168603410
# Sun4608              3.45      Douglas Tucker  4478071379779230
# ...

# %%
df[(df['total_bill']>45)]
# Out:
#          total_bill    tip   sex smoker  day    time  size  price_per_person  \
# Sat8139       48.27   6.73  Male     No  Sat  Dinner     4             12.07
# Sun7518       48.17   5.00  Male     No  Sun  Dinner     6              8.03
# Sat1954       50.81  10.00  Male    Yes  Sat  Dinner     3             16.94
# Sun2337       45.35   3.50  Male    Yes  Sun  Dinner     3             15.12
# Sat4590       48.33   9.00  Male     No  Sat  Dinner     4             12.08
#
#               Payer Name         CC Number  price_perperson  \
# Sat8139      Brian Ortiz  6596453823950595            12.07
# Sun7518    Ryan Gonzales  3523151482063321             8.03
# Sat1954    Gregory Clark  5473850968388236            16.94
# Sun2337     Jose Parsons  4112207559459910            15.12
# Sat4590  Alex Williamson      676218815212            12.08
#
#          bill_greater_than20
# Sat8139                 True
# Sun7518                 True
# Sat1954                 True
# ...

# %%
df[df['size']>5]
# Out:
#           total_bill  tip     sex smoker   day    time  size  \
# Thur3948       29.80  4.2  Female     No  Thur   Lunch     6
# Thur1025       34.30  6.7    Male     No  Thur   Lunch     6
# Thur6179       27.05  5.0  Female     No  Thur   Lunch     6
# Sun7518        48.17  5.0    Male     No   Sun  Dinner     6
#
#           price_per_person      Payer Name         CC Number  price_perperson  \
# Thur3948              4.97  Angela Sanchez      503857080488             4.97
# Thur1025              5.72  Steven Carlson  3526515703718508             5.72
# Thur6179              4.51    Regina Jones     4311048695487             4.51
# Sun7518               8.03   Ryan Gonzales  3523151482063321             8.03
#
#           bill_greater_than20
# Thur3948                 True
# Thur1025                 True
# Thur6179                 True
# Sun7518                  True

# %%
df[df['tip']>6]
# Out:
#           total_bill    tip     sex smoker   day    time  size  \
# Sat239         39.42   7.58    Male     No   Sat  Dinner     4
# Sat8139        48.27   6.73    Male     No   Sat  Dinner     4
# Thur1025       34.30   6.70    Male     No  Thur   Lunch     6
# Sat1954        50.81  10.00    Male    Yes   Sat  Dinner     3
# Sun6059        23.17   6.50    Male    Yes   Sun  Dinner     4
# Sat4590        48.33   9.00    Male     No   Sat  Dinner     4
# Sat3374        28.17   6.50  Female    Yes   Sat  Dinner     3
#
#           price_per_person         Payer Name         CC Number  \
# Sat239                9.86     Lance Peterson  3542584061609808
# Sat8139              12.07        Brian Ortiz  6596453823950595
# Thur1025              5.72     Steven Carlson  3526515703718508
# Sat1954              16.94      Gregory Clark  5473850968388236
# Sun6059               5.79  Dr. Michael James     4718501859162
# Sat4590              12.08    Alex Williamson      676218815212
# ...

# %%
# df[df['sex']=="Female"]
# df['total_bill']>35

df[(df['sex']=="Female") & (df['total_bill']>35)]
# Out:
#           total_bill   tip     sex smoker   day    time  size  \
# Sun6686        35.26  5.00  Female     No   Sun  Dinner     4
# Sat6240        44.30  2.50  Female    Yes   Sat  Dinner     3
# Thur9313       43.11  5.00  Female    Yes  Thur   Lunch     4
# Sat9777        35.83  4.67  Female     No   Sat  Dinner     3
#
#           price_per_person      Payer Name         CC Number  price_perperson  \
# Sun6686               8.82    Diane Macias  4577817359320969             8.82
# Sat6240              14.77   Heather Cohen   379771118886604            14.77
# Thur9313             10.78     Brooke Soto  5544902205760175            10.78
# Sat9777              11.94  Kimberly Crane      676184013727            11.94
#
#           bill_greater_than20
# Sun6686                  True
# Sat6240                  True
# Thur9313                 True
# Sat9777                  True

# %%
checkDays = ['Mon', 'Tues','Wed','Thur']

df['day'].isin(checkDays)
# Out:
# Sun2959    False
# Sun4608    False
# Sun4458    False
# Sun5260    False
# Sun2251    False
#            ...
# Sat1766    False
# Sat3880    False
# Sat17      False
# Thur672     True
# Sun2959    False
# Name: day, Length: 245, dtype: bool

# %%
df[df['day'].isin(checkDays)]

# or
# df[df['day'].isin(['Mon', 'Tues','Wed','Thur'])]
# Out:
#           total_bill   tip     sex smoker   day    time  size  \
# Thur4924       27.20  4.00    Male     No  Thur   Lunch     4
# Thur2863       22.76  3.00    Male     No  Thur   Lunch     2
# Thur9501       17.29  2.71    Male     No  Thur   Lunch     2
# Thur6453       19.44  3.00    Male    Yes  Thur   Lunch     2
# Thur8232       16.66  3.40    Male     No  Thur   Lunch     2
# ...              ...   ...     ...    ...   ...     ...   ...
# Thur1301       13.00  2.00  Female    Yes  Thur   Lunch     2
# Thur7770       16.40  2.50  Female    Yes  Thur   Lunch     2
# Thur2160       20.53  4.00    Male    Yes  Thur   Lunch     4
# Thur8084       16.47  3.23  Female    Yes  Thur   Lunch     3
# Thur672        18.78  3.00  Female     No  Thur  Dinner     2
#
#           price_per_person       Payer Name         CC Number  \
# Thur4924              6.80       John Davis    30344778738589
# Thur2863             11.38       Chris Hahn  3591887177014031
# ...
