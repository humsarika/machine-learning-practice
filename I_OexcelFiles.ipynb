# %% [markdown]
# <a href="https://colab.research.google.com/github/sarika-kushwaha/data-science-colab-notebook/blob/main/I_OexcelFiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Libraries
#
# xlrd - it is reading data and formatting information for old excel files that is xls
#
# openpyxl - It uses the newer excel files ie. .xlsx

# %%
df = pd.read_excel('emp.xlsx',sheet_name = 'Sheet1')

# %%
df
# Out:
#              number  first_name last_name   gender birth_date  \
# 0               NaN       483.0    Lenord     Kihn          M
# 1               NaN       478.0     Palma   Beahan          F
# 2               NaN       348.0    Hebert   Muller          M
# 3               NaN       757.0  Virginia  Ullrich          M
# 4               NaN       937.0      Roby   Hudson          M
# ...             ...         ...       ...      ...        ...
# 997             NaN       126.0  Kimberli   Walter          M
# 998             NaN       277.0   Talmage  Bartell          F
# 999             NaN       960.0    Laurie   Nienow          M
# 1000    @sarikaji22         NaN       NaN      NaN        NaN
# 1001  Write Preview         NaN       NaN      NaN        NaN
#
#      employment_status annual_salary  tax_file_no
# 0           1994-07-01           NaN      64598.0
# 1           1972-05-06            PE     124103.0
# 2           1990-09-04            PE     100324.0
# ...

# %%
df = pd.ExcelFile('emp.xlsx')

# %%
df.sheet_names
# Out:
# ['Sheet1']

# %%
excel_sheet_dict = pd.read_excel('emp.xlsx',sheet_name=None)

# %%
type(excel_sheet_dict)
# Out:
# dict

# %% [markdown]
# it is dictionary type so it has keys

# %%
excel_sheet_dict.keys()
# Out:
# dict_keys(['Sheet1'])

# %%
excel_sheet_dict['Sheet1']
# Out:
#              number  first_name last_name   gender birth_date  \
# 0               NaN       483.0    Lenord     Kihn          M
# 1               NaN       478.0     Palma   Beahan          F
# 2               NaN       348.0    Hebert   Muller          M
# 3               NaN       757.0  Virginia  Ullrich          M
# 4               NaN       937.0      Roby   Hudson          M
# ...             ...         ...       ...      ...        ...
# 997             NaN       126.0  Kimberli   Walter          M
# 998             NaN       277.0   Talmage  Bartell          F
# 999             NaN       960.0    Laurie   Nienow          M
# 1000    @sarikaji22         NaN       NaN      NaN        NaN
# 1001  Write Preview         NaN       NaN      NaN        NaN
#
#      employment_status annual_salary  tax_file_no
# 0           1994-07-01           NaN      64598.0
# 1           1972-05-06            PE     124103.0
# 2           1990-09-04            PE     100324.0
# ...

# %%
excel_sheet_dict
# Out:
# {'Sheet1':              number  first_name last_name   gender birth_date  \
#  0               NaN       483.0    Lenord     Kihn          M
#  1               NaN       478.0     Palma   Beahan          F
#  2               NaN       348.0    Hebert   Muller          M
#  3               NaN       757.0  Virginia  Ullrich          M
#  4               NaN       937.0      Roby   Hudson          M
#  ...             ...         ...       ...      ...        ...
#  997             NaN       126.0  Kimberli   Walter          M
#  998             NaN       277.0   Talmage  Bartell          F
#  999             NaN       960.0    Laurie   Nienow          M
#  1000    @sarikaji22         NaN       NaN      NaN        NaN
#  1001  Write Preview         NaN       NaN      NaN        NaN
#
#       employment_status annual_salary  tax_file_no
#  0           1994-07-01           NaN      64598.0
#  1           1972-05-06            PE     124103.0
# ...

# %%
our_df = excel_sheet_dict['Sheet1']

# %%
our_df
# Out:
#              number  first_name last_name   gender birth_date  \
# 0               NaN       483.0    Lenord     Kihn          M
# 1               NaN       478.0     Palma   Beahan          F
# 2               NaN       348.0    Hebert   Muller          M
# 3               NaN       757.0  Virginia  Ullrich          M
# 4               NaN       937.0      Roby   Hudson          M
# ...             ...         ...       ...      ...        ...
# 997             NaN       126.0  Kimberli   Walter          M
# 998             NaN       277.0   Talmage  Bartell          F
# 999             NaN       960.0    Laurie   Nienow          M
# 1000    @sarikaji22         NaN       NaN      NaN        NaN
# 1001  Write Preview         NaN       NaN      NaN        NaN
#
#      employment_status annual_salary  tax_file_no
# 0           1994-07-01           NaN      64598.0
# 1           1972-05-06            PE     124103.0
# 2           1990-09-04            PE     100324.0
# ...

# %%
our_df.to_excel('Employee.xlsx',sheet_name = 'Sheet1')

# %%
our_df.drop(axis = 0,index = 1001)
# Out:
#            number  first_name last_name   gender birth_date employment_status  \
# 0             NaN       483.0    Lenord     Kihn          M        1994-07-01
# 1             NaN       478.0     Palma   Beahan          F        1972-05-06
# 2             NaN       348.0    Hebert   Muller          M        1990-09-04
# 3             NaN       757.0  Virginia  Ullrich          M        1991-09-23
# 4             NaN       937.0      Roby   Hudson          M        1997-01-15
# ...           ...         ...       ...      ...        ...               ...
# 996           NaN       132.0     Maxim      Orn          M        1971-03-01
# 997           NaN       126.0  Kimberli   Walter          M        1976-03-07
# 998           NaN       277.0   Talmage  Bartell          F        1989-02-19
# 999           NaN       960.0    Laurie   Nienow          M        1993-04-01
# 1000  @sarikaji22         NaN       NaN      NaN        NaN               NaT
#
#      annual_salary  tax_file_no
# ...

# %%
our_df
# Out:
#       first_name last_name   gender birth_date employment_status  \
# 0          483.0    Lenord     Kihn          M        1994-07-01
# 1          478.0     Palma   Beahan          F        1972-05-06
# 2          348.0    Hebert   Muller          M        1990-09-04
# 3          757.0  Virginia  Ullrich          M        1991-09-23
# 4          937.0      Roby   Hudson          M        1997-01-15
# ...          ...       ...      ...        ...               ...
# 996        132.0     Maxim      Orn          M        1971-03-01
# 997        126.0  Kimberli   Walter          M        1976-03-07
# 998        277.0   Talmage  Bartell          F        1989-02-19
# 999        960.0    Laurie   Nienow          M        1993-04-01
# 1001         NaN       NaN      NaN        NaN               NaT
#
#      annual_salary  tax_file_no
# 0              NaN      64598.0
# 1               PE     124103.0
# 2               PE     100324.0
# 3               PE     144957.0
# ...

# %%
our_df = our_df.drop(axis = 0,index = 1001)

# %%
our_df = our_df.drop('number',axis = 1)

# %%
our_df.columns = ['Number','first_name'	,'last_name','gender','birth_date',	'employment_status','annual_salary']

# %%
our_df
# Out:
#      Number first_name last_name gender birth_date employment_status  \
# 0     483.0     Lenord      Kihn      M 1994-07-01               NaN
# 1     478.0      Palma    Beahan      F 1972-05-06                PE
# 2     348.0     Hebert    Muller      M 1990-09-04                PE
# 3     757.0   Virginia   Ullrich      M 1991-09-23                PE
# 4     937.0       Roby    Hudson      M 1997-01-15               NaN
# ..      ...        ...       ...    ...        ...               ...
# 995   712.0       Dann    Crooks    NaN 1983-12-25                CA
# 996   132.0      Maxim       Orn      M 1971-03-01                CA
# 997   126.0   Kimberli    Walter      M 1976-03-07                CA
# 998   277.0    Talmage   Bartell      F 1989-02-19                PE
# 999   960.0     Laurie    Nienow      M 1993-04-01                PE
#
#      annual_salary
# 0          64598.0
# 1         124103.0
# 2         100324.0
# 3         144957.0
# 4         137659.0
# ...

# %%
our_df.to_excel('Employee.xlsx',sheet_name = 'Sheet1')
